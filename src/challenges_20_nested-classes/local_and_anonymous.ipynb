# %% [markdown]
# First, you need to create a record named `Employee`, that contains a first name, a last name, and a hire date.
# Setup a list of `Employees` with various names and hire dates in the main method.
# Setup a new method that takes this list of `Employees` as a parameter.
# Create a local class in this method (pass `Employee` to the constructor and include a field for this), and add some calculated fields, such as full name, and years worked.
#
# Create a list of employees using your local class.
# Create an anonymous class to sort your local class employees, by full name, or years worked.
# Print the sorted list.
# Hint: Here is a date function, which should help you with calculating years worked.
#
# ![image.png](attachment:image.png)
#
# A possible output
#
# ![image-2.png](attachment:image-2.png)
