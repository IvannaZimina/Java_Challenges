# %% [markdown]
# - Create the `Worker` class, the `Employee` class, the `SalariedEmployee` and the `HourlyEmployee` class.
# - For each class, create the attributes and methods shown on this diagram.
# - Create a `main` method that will create a `SalariedEmployee` and a `HourlyEmployee`, and call the methods `getAge`, `collectPay`, and the methods shown for the subclasses, `retire` and `getDoublePay`.
#
# ![image.png](attachment:image.png)
#
# A salaried employee is paid based on some percentage of his or her annual salary.
#
# If this person is retired, then the salary may be 100 percent of this amount, but it is generally reduced somewhat.
#
# An hourly employee is paid by the hours worked and the hourly rate they agreed to work for.
#
# An hourly employee may also get double pay if they work over a certain number of hours.
#
# Each method call made on these objects points to the code that will be executed.
#
# When Liisi or Priit call `getAge()`, the method's implementation is on `Worker` and is not overridden by any other class, so the `getAge` method on `Worker` is executed.
#
# When Liisi or Priit call `toString()`, this method has been overridden twice, first by `Worker`, and then by `Employee`. But it wasn't overridden by either `SalariedEmployee` or `HourlyEmployee`, so the method from the `Employee` class is the one that's used.
#
# Looking at the `collectPay` method, this method was overridden by both `SalariedEmployee`, and `HourlyEmployee`.
#
# Liisi will execute the method on `SalariedEmployee`.
#
# Priit will execute the one on `HourlyEmployee`.
#
# `SalariedEmployee` has a method, `retire`, that's not overridden, meaning it's only in that class; it's a method specific to a salaried employee.
#
# `HourlyEmployee` has its own method, `getDoublePay`, which wouldn't apply to a salaried employee, so we declared it in this class and not in any super class.
#
# ![image-2.png](attachment:image-2.png)
#
# Looking at the `collectPay` method, this method was overridden by both `SalariedEmployee`, and `HourlyEmployee`.
#
# Liisi will execute the method on `SalariedEmployee`.
#
# Priit will execute the one on `HourlyEmployee`.
#
# `SalariedEmployee` has a method, `retire`, that's not overridden, meaning it's only in that class; it's a method specific to a salaried employee.
#
# `HourlyEmployee` has its own method, `getDoublePay`, which wouldn't apply to a salaried employee, so we declared it in this class and not in any super class.
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Step-by-Step Plan (Detailed)
#
# 1. Create the base class `Worker`.
#    Add common fields that every person in your model should have (for example name, birth date, or similar fields from your diagram).
#    Implement `getAge()` in this class, because age calculation is shared behavior.
#    Implement `toString()` in this class as the first readable object description.
#
# 2. Create the class `Employee` that extends `Worker`.
#    Add employee-specific data (for example employee id, hire date, and other fields shown in the diagram).
#    Override `toString()` to include both worker and employee information.
#    Define a `collectPay()` method here only if your diagram requires a default behavior at this level.
#
# 3. Create the class `SalariedEmployee` that extends `Employee`.
#    Add salary-specific fields (for example annual salary and retirement status).
#    Override `collectPay()` so payment is calculated from annual salary according to your task rules.
#    Add `retire()` method that changes the employee status and updates payment logic for retired state.
#
# 4. Create the class `HourlyEmployee` that extends `Employee`.
#    Add hourly-specific fields (for example hourly rate and hours worked).
#    Override `collectPay()` so payment is based on hours and hourly rate.
#    Add `getDoublePay()` method for overtime or special conditions required by the task.
#
# 5. Verify method inheritance and overriding.
#    Confirm that `getAge()` comes from `Worker` for both subclasses.
#    Confirm that `toString()` resolution follows override rules and uses the `Employee` version if subclasses do not override it.
#    Confirm that `collectPay()` uses subclass implementations (`SalariedEmployee` and `HourlyEmployee`).
#
# 6. Implement a `main` method for demonstration.
#    Create one `SalariedEmployee` object and one `HourlyEmployee` object.
#    Call `getAge()` for both objects.
#    Call `collectPay()` for both objects.
#    Call `retire()` on the salaried employee and observe the changed behavior.
#    Call `getDoublePay()` on the hourly employee and print the result.
#
# 7. Print a clear output report.
#    Print labels before each method call so it is obvious which object and method are being tested.
#    Include object data with `toString()` to show polymorphic behavior and inheritance clearly.
#
# 8. Test edge cases.
#    Test salaried payment before and after retirement.
#    Test hourly payment with normal hours and with overtime if your rules include overtime logic.
#    Test that methods unavailable for a class are not called on the wrong type.
#
# 9. Keep the implementation clean.
#    Use constructors to initialize all required fields.
#    Keep responsibilities separated: shared logic in superclasses, specific logic in subclasses.
#    Use meaningful method names and consistent formatting so the inheritance structure is easy to read.
#
# 10. Final checklist before submission.
#    Ensure all four classes are present and connected correctly with `extends`.
#    Ensure required methods exist with correct names.
#    Ensure overridden methods are actually overriding (use `@Override` where appropriate).
#    Ensure `main` demonstrates all required method calls from the task.
